# %%
# Out:
# Running cells with 'env (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Alejandro/OneDrive/SecondBrain/Estudio/PLATZI/Escuela de Python/Curso de Python para Ciencia de Datos/Curso de ciencias de Daatos/env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# Hola Mundo
