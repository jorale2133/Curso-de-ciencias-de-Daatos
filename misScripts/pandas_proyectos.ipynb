# %% [markdown]
# Proyecto de ciencia de datos

# %%
import kagglehub
import shutil
import os

#1. Descarga a la cache
cahe_path = kagglehub.dataset_download("aishwaryamuthukumar/cars-dataset-audi-bmw-ford-hyundai-skoda-vw")

#2. Definirruta especifica
destino = "./datos_autos"

#3. Mover los archivos

if not os.path.exists(destino):
    # Usamos move para no duplicar espacio en disco, o copytree si quieres mantener la caché
    shutil.move(cahe_path, destino)
    print(f"✅ Archivos movidos con éxito a: {os.path.abspath(destino)}")
else:
    print(f"⚠️ La carpeta '{destino}' ya existe. Borra la carpeta o elige otro nombre.")
# Out:
# ...
# 100%|██████████| 708k/708k [00:00<00:00, 4.52MB/s]
# Extracting files...
# ⚠️ La carpeta './datos_autos' ya existe. Borra la carpeta o elige otro nombre.

# %% [markdown]
# Cargar Datos a pandas

# %%
import pandas as pd

path = "./datos_autos/cars_dataset.csv"
cars_data = pd.read_csv(path, encoding='ISO-8859-1')
print(cars_data)
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3           A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4           A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72430      I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431      I40  2015   7830       Manual    59508   Diesel   30.0  65.7
# 72432      I10  2017   6830       Manual    13810   Petrol   20.0  60.1
# 72433   Tucson  2018  13994       Manual    23313   Petrol  145.0  44.8
# 72434   Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 0             1.4     audi
# 1             2.0     audi
# ...

# %% [markdown]
# Obtener información de cars_data

# %%
#información de columnas
columns_names = cars_data.columns
print(columns_names)
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'Make'],
#       dtype='str')

# %% [markdown]
# Obtención del tamaño de las final y columnas

# %%
#Dimensión de columnas y filas
num_rows, num_columns = cars_data.shape
print('Numero de filas', num_rows)
print('Numero de columnas', num_columns)
# Out:
# Numero de filas 72435
# Numero de columnas 10

# %% [markdown]
# Resumen estadítico de los datos

# %%
summary = cars_data.describe()
print(summary)
# Out:
#                year          price        mileage           tax           mpg  \
# count  72435.000000   72435.000000   72435.000000  72435.000000  72435.000000
# mean    2017.073666   16580.158708   23176.517057    116.953407     55.852480
# std        2.101252    9299.028754   21331.515562     64.045533     17.114391
# min     1996.000000     495.000000       1.000000      0.000000      0.300000
# 25%     2016.000000   10175.000000    7202.500000     30.000000     47.900000
# 50%     2017.000000   14495.000000   17531.000000    145.000000     55.400000
# 75%     2019.000000   20361.000000   32449.000000    145.000000     62.800000
# max     2020.000000  145000.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  72435.000000
# mean       1.635650
# std        0.561535
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        6.600000

# %% [markdown]
# Datos de la columna engineSize

# %%
cars_engine_size = cars_data['engineSize']
print(cars_engine_size)
# Out:
# 0        1.4
# 1        2.0
# 2        1.4
# 3        2.0
# 4        1.0
#         ...
# 72430    1.6
# 72431    1.7
# 72432    1.0
# 72433    1.6
# 72434    1.7
# Name: engineSize, Length: 72435, dtype: float64

# %% [markdown]
# Información estadítica del tamaño del motor.

# %%
## Media
mean_value = cars_engine_size.mean()
print('La media es:', mean_value)
## Mediana
media_value = cars_engine_size.median()
print('La mediana es:', media_value)
##Suma total de las columna
sum_value = cars_engine_size.sum()
print('La suma total es:', sum_value)
##Contar el total de valores
count_values = cars_engine_size.count()
print('Valores contados:', count_values)
# Out:
# La media es: 1.6356498930075238
# La mediana es: 1.6
# La suma total es: 118478.29999999999
# Valores contados: 72435

# %% [markdown]
# Información de las cabeceras de las columnas

# %%
cars_data.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi
